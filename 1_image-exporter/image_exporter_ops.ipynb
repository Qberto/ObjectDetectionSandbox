# %% [markdown]
# # Crowd Detection Project - Image Exporter
#
# This process generates training and testing data for image classification from video feeds given ground-truth data found in a feature class.

# %% [markdown]
# ## Pseudocode
#
# 1. Import needed modules
#
# 2. Establish runtime variables
#     - GIS
#     - video root directory
#     - labels feature class
#     - labels FC camera field
#     - labels FC label field
#     - labels FC datetime field
#
# 3. Create Helper Functions:
#     - Input: label FC record (datetime, label, camera) | Output: video url and timestamp
#
# 4. Iteration: For each record of the labeled feature class...
#     - Run helper function to determine video url and timestamp
#     - Determine output path
#     - Run export using moviepy

# %% [markdown]
# ### 1. Import needed modules

# %%
import arcgis
import moviepy.editor as mpy
import datetime
import os

# %% [markdown]
# ### 2. Establish runtime variables

# %% [markdown]
# - GIS
# - video root directory
# - labels feature class
# - labels FC camera field
# - labels FC label field
# - labels FC datetime field

# %%
gis = arcgis.gis.GIS("https://esrifederal.maps.arcgis.com", username="Anieto_esrifederal")
# Out:
# Enter password: ········

# %%
# Make reference to directories and other needed paths
video_root_dir = r"D:\5_Data\Transportation\Cameras\SunTrustPark"
labels_fc = r"D:\3_Sandbox_Projects\1806_CobbCounty_PedestrianDetection\Inputs\S123_Labels.gdb\PedestrianCount"
labels_fc_camera_field = "CameraID"
labels_fc_label_field = "degreesaturation"
labels_fc_datetime_field = "PhotoDateTime"

# %% [markdown]
# ### UnitTests

# %%
ix = 0

# %%
ts = labels_sdf.iloc[ix]['PhotoDateTime']
ts
# Out:
# Timestamp('2018-06-13 01:58:00')

# %%
camera = labels_sdf.iloc[ix]['CameraID']
camera
# Out:
# '129'

# %%
pdt = ts.to_pydatetime()
pdt
# Out:
# datetime.datetime(2018, 6, 13, 1, 58)

# %%
pdt = pdt - datetime.timedelta(hours=4)
pdt
# Out:
# datetime.datetime(2018, 6, 12, 21, 58)

# %%
yymmdd = pdt.strftime("%y%m%d")
yymmdd
# Out:
# '180612'

# %%
hh = pdt.strftime("%H")
hh
# Out:
# '21'

# %%
mm = pdt.strftime("%M")
mm
# Out:
# '58'

# %%
ss = pdt.strftime("%S")
ss
# Out:
# '00'

# %%
video_files = os.listdir("{0}\\{1}\\{2}".format(video_root_dir, yymmdd, camera))
video_files
# Out:
# ['21h39m58s.avi', '22h29m30s.avi', '23h21m50s.avi']

# %% [markdown]
# ### 3. Create Helper Functions

# %%
# Input: List of video files with names HHhMMmSSs.avi, datetime object | Output: Video containing the datetime
def get_videopath_and_video_timestamp_from_label_timestamp(video_files, datetime_object):
    
    # For each file in video files...
    for ix, video_file in enumerate(video_files):
    
        # we need a datetime range...
        start = datetime.datetime.strptime(video_files[ix]+" "+yymmdd, "%Hh%Mm%Ss.avi %y%m%d")
        end = datetime.datetime.strptime(video_files[ix+1]+" "+yymmdd, "%Hh%Mm%Ss.avi %y%m%d")
        in_time_range = start <= datetime_object <= end
        
        # so we can determine if the current timeslot exists there
        if in_time_range:
            
            # And get the video timestamp
            delta_video_timestamp = datetime_object - start
           
            return video_file, str(delta_video_timestamp)

# %%
# Unittest for get_videopath_and_video_timestamp_from_label_timestamp
get_videopath_and_video_timestamp_from_label_timestamp(video_files, pdt)
# Out:
# ('21h39m58s.avi', '0:18:02')

# %%
# Input: label FC record (datetime, label, camera) | Output: video url and timestamp
def retrieve_video_and_time(camera, 
                            label, 
                            pandas_timestamp,
                            video_root_dir):
    
    # This function relies on a video root directory structure as follows:
    
    # Root_Path
        # yymmdd
            # Camera ID
                # HHhMMmSSs.avi
                
    # Convert pandas timestamp to python datetime object
    pdt = pandas_timestamp.to_pydatetime()
    pdt = pdt - datetime.timedelta(hours=4)
    print(pdt)
    
    # Parse out datetime object into needed formats
    yymmdd = pdt.strftime("%y%m%d")
    hh = pdt.strftime("%H")
    mm = pdt.strftime("%M")
    ss = pdt.strftime("%S")
    
    # Determine which video contains the needed time and at which time the label was recorded in the video
    camera_dir = "{0}\\{1}\\{2}".format(video_root_dir, yymmdd, camera)
    video_files = os.listdir(camera_dir)
    video_name, video_time = get_videopath_and_video_timestamp_from_label_timestamp(video_files, pdt)
    
    return "{0}\\{1}".format(camera_dir, video_name), video_time

# %%
ts
# Out:
# Timestamp('2018-06-13 01:58:00')

# %%
retrieve_video_and_time(camera, "High", ts, video_root_dir)
# Out:
# 2018-06-12 21:58:00
# ('D:\\5_Data\\Transportation\\Cameras\\SunTrustPark\\180612\\129\\21h39m58s.avi',
#  '0:18:02')

# %% [markdown]
# ### 4.Iteration: For each record of the labeled feature class...
#     - Run helper function to determine video url and timestamp
#     - Determine output path
#     - Run export using moviepy

# %%
def main(label_fc, labels_fc_camera_field, labels_fc_label_field, labels_fc_datetime_field, video_root_dir):
    # Convert the labels fc into a spatial dataframe in python memory
    labels_sdf = arcgis.features.SpatialDataFrame.from_featureclass(labels_fc)
    # Iterate on each record to start the image export
    for index, row in labels_sdf.iterrows():
        
        camera = row[labels_fc_camera_field] 
        label = row[labels_fc_label_field]
        pandas_timestamp = row[labels_fc_datetime_field]
        
        print("\n<<<< >>>>")
        print(camera)
        print(label)
        print(pandas_timestamp)
        print("\n")
                
        # Get the path to the right video and the timestamp in the video for the recorded label
        video_path, video_time =  retrieve_video_and_time(camera, label, pandas_timestamp, video_root_dir)
        print(video_path, video_time)
        
#         video_path = r"D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\18h57m39s.avi"
#         clip = mpy.VideoFileClip(video_path)
#         clip.save_frame("testframe.png")
#         clip.save_frame("testframe02.png", t='00:28:55')

# %%
# Make reference to directories and other needed paths
video_root_dir = r"D:\5_Data\Transportation\Cameras\SunTrustPark"
labels_fc = r"D:\3_Sandbox_Projects\1806_CobbCounty_PedestrianDetection\Inputs\S123_Labels.gdb\PedestrianCount"
labels_fc_camera_field = "CameraID"
labels_fc_label_field = "degreesaturation"
labels_fc_datetime_field = "PhotoDateTime"

# Run main
main(labels_fc, labels_fc_camera_field, labels_fc_label_field, labels_fc_datetime_field, video_root_dir)
# Out:
# <<<< >>>>
# 129
# Medium
# 2018-06-13 01:58:00
#
#
# 2018-06-12 21:58:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:18:02
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 01:59:00
#
#
# 2018-06-12 21:59:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:43:28
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:00:00
#
#
# 2018-06-12 22:00:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:20:02
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:01:00
#
#
# 2018-06-12 22:01:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:21:02
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:01:00
#
#
# 2018-06-12 22:01:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:45:28
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:02:00
#
#
# 2018-06-12 22:02:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:22:02
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:04:00
#
#
# 2018-06-12 22:04:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:24:02
#
# <<<< >>>>
# 128
# Low
# 2018-06-13 02:04:00
#
#
# 2018-06-12 22:04:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 2:04:03
#
# <<<< >>>>
# 128
# None
# 2018-06-13 02:03:00
#
#
# 2018-06-12 22:03:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 2:03:03
#
# <<<< >>>>
# 128
# Low
# 2018-06-13 02:02:00
#
#
# 2018-06-12 22:02:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 2:02:03
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 02:00:00
#
#
# 2018-06-12 22:00:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 2:00:03
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 01:59:00
#
#
# 2018-06-12 21:59:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 1:59:03
#
# <<<< >>>>
# 128
# Low
# 2018-06-13 01:57:00.000001
#
#
# 2018-06-12 21:57:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 1:57:03.000001
#
# <<<< >>>>
# 128
# Low
# 2018-06-13 01:55:00
#
#
# 2018-06-12 21:55:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 1:55:03
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 01:54:00.000001
#
#
# 2018-06-12 21:54:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 1:54:03.000001
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 01:54:00.000001
#
#
# 2018-06-12 21:54:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\19h59m57s.avi 1:54:03.000001
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:05:00
#
#
# 2018-06-12 22:05:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:25:02
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:07:00
#
#
# 2018-06-12 22:07:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:27:02
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:07:00
#
#
# 2018-06-12 22:07:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:51:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:09:00
#
#
# 2018-06-12 22:09:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:53:28
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:09:00
#
#
# 2018-06-12 22:09:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:29:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:10:00.000001
#
#
# 2018-06-12 22:10:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:54:28.000001
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:11:00
#
#
# 2018-06-12 22:11:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:31:02
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:11:00
#
#
# 2018-06-12 22:11:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:55:28
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:12:00
#
#
# 2018-06-12 22:12:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:32:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:12:00
#
#
# 2018-06-12 22:12:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:32:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:13:00
#
#
# 2018-06-12 22:13:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:33:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:14:00
#
#
# 2018-06-12 22:14:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:34:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:14:00
#
#
# 2018-06-12 22:14:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:34:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:14:00
#
#
# 2018-06-12 22:14:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:58:28
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:14:00
#
#
# 2018-06-12 22:14:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:34:02
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:15:00
#
#
# 2018-06-12 22:15:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:35:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:16:00
#
#
# 2018-06-12 22:16:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:00:28
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:16:00
#
#
# 2018-06-12 22:16:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:36:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:17:00
#
#
# 2018-06-12 22:17:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:37:02
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 02:17:00
#
#
# 2018-06-12 22:17:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\22h08m20s.avi 0:08:40
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 02:15:00
#
#
# 2018-06-12 22:15:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\22h08m20s.avi 0:06:40
#
# <<<< >>>>
# 128
# High
# 2018-06-13 02:11:00
#
#
# 2018-06-12 22:11:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\22h08m20s.avi 0:02:40
#
# <<<< >>>>
# 128
# Medium
# 2018-06-13 02:11:00
#
#
# 2018-06-12 22:11:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\128\22h08m20s.avi 0:02:40
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:18:00
#
#
# 2018-06-12 22:18:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:38:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:18:00
#
#
# 2018-06-12 22:18:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:38:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:19:00
#
#
# 2018-06-12 22:19:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:03:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:19:00
#
#
# 2018-06-12 22:19:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:03:28
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:20:00
#
#
# 2018-06-12 22:20:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:40:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:20:00
#
#
# 2018-06-12 22:20:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:04:28
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:21:00
#
#
# 2018-06-12 22:21:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:41:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:21:00
#
#
# 2018-06-12 22:21:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:05:28
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:22:00
#
#
# 2018-06-12 22:22:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:42:02
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:23:00.000001
#
#
# 2018-06-12 22:23:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:07:28.000001
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:23:00.000001
#
#
# 2018-06-12 22:23:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:43:02.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:23:00.000001
#
#
# 2018-06-12 22:23:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:07:28.000001
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:24:00
#
#
# 2018-06-12 22:24:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:44:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:26:00.000001
#
#
# 2018-06-12 22:26:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:46:02.000001
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:26:00.000001
#
#
# 2018-06-12 22:26:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:46:02.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:26:00.000001
#
#
# 2018-06-12 22:26:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:10:28.000001
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:27:00
#
#
# 2018-06-12 22:27:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:47:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:28:00
# 2018-06-12 22:28:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\21h39m58s.avi 0:48:02
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:30:00
#
#
# 2018-06-12 22:30:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:00:30
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:30:00
#
#
# 2018-06-12 22:30:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:00:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:31:00
#
#
# 2018-06-12 22:31:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:02:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:31:00
#
#
# 2018-06-12 22:31:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:02:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:32:00
#
#
# 2018-06-12 22:32:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:03:30
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:32:00
#
#
# 2018-06-12 22:32:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:02:30
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:34:00
#
#
# 2018-06-12 22:34:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:04:30
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:37:00
#
#
# 2018-06-12 22:37:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:07:30
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:38:00
#
#
# 2018-06-12 22:38:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:08:30
#
# <<<< >>>>
# 129
# High
# 2018-06-13 02:42:00.000001
#
#
# 2018-06-12 22:42:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:12:30.000001
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:44:00
#
#
# 2018-06-12 22:44:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:14:30
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:45:00
#
#
# 2018-06-12 22:45:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:15:30
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:46:00
#
#
# 2018-06-12 22:46:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:16:30
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:47:00
#
#
# 2018-06-12 22:47:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:17:30
#
# <<<< >>>>
# 129
# Medium
# 2018-06-13 02:49:00
#
#
# 2018-06-12 22:49:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\129\22h29m30s.avi 0:19:30
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:55:00.000001
#
#
# 2018-06-12 22:55:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:26:30.000001
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:52:00
#
#
# 2018-06-12 22:52:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:23:30
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:51:00
#
#
# 2018-06-12 22:51:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:22:30
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:50:00
#
#
# 2018-06-12 22:50:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:21:30
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:46:00
#
#
# 2018-06-12 22:46:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:17:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:44:00
#
#
# 2018-06-12 22:44:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:15:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:41:00
#
#
# 2018-06-12 22:41:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:12:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:41:00
#
#
# 2018-06-12 22:41:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:12:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:41:00
#
#
# 2018-06-12 22:41:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:12:30
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:39:00.000001
#
#
# 2018-06-12 22:39:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:10:30.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:39:00.000001
#
#
# 2018-06-12 22:39:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:10:30.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:38:00
#
#
# 2018-06-12 22:38:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:09:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:37:00
#
#
# 2018-06-12 22:37:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:08:30
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:35:00
#
#
# 2018-06-12 22:35:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:06:30
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:34:00
#
#
# 2018-06-12 22:34:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:05:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:32:00
#
#
# 2018-06-12 22:32:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:03:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:31:00
#
#
# 2018-06-12 22:31:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:02:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:31:00
#
#
# 2018-06-12 22:31:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:02:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:30:00
#
#
# 2018-06-12 22:30:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:01:30
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:30:00
#
#
# 2018-06-12 22:30:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\22h28m30s.avi 0:01:30
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:28:00
#
#
# 2018-06-12 22:28:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:12:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:27:00
#
#
# 2018-06-12 22:27:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:11:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:27:00
#
#
# 2018-06-12 22:27:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:11:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:26:00.000001
#
#
# 2018-06-12 22:26:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:10:28.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:23:00.000001
#
#
# 2018-06-12 22:23:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:07:28.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:23:00.000001
#
#
# 2018-06-12 22:23:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:07:28.000001
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:22:00
#
#
# 2018-06-12 22:22:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:06:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:22:00
#
#
# 2018-06-12 22:22:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:06:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:20:00
#
#
# 2018-06-12 22:20:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 1:04:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:14:00
#
#
# 2018-06-12 22:14:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:58:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:13:00
#
#
# 2018-06-12 22:13:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:57:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:11:00
#
#
# 2018-06-12 22:11:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:55:28
#
# <<<< >>>>
# 130
# High
# 2018-06-13 02:10:00.000001
#
#
# 2018-06-12 22:10:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:54:28.000001
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:08:00
#
#
# 2018-06-12 22:08:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:52:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:07:00
#
#
# 2018-06-12 22:07:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:51:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:05:00
#
#
# 2018-06-12 22:05:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:49:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 02:04:00
#
#
# 2018-06-12 22:04:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:48:28
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 02:02:00
#
#
# 2018-06-12 22:02:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:46:28
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 01:58:00
#
#
# 2018-06-12 21:58:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:42:28
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 01:56:00
#
#
# 2018-06-12 21:56:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:40:28
#
# <<<< >>>>
# 130
# Medium
# 2018-06-13 01:54:00.000001
#
#
# 2018-06-12 21:54:00.000001
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:38:28.000001
#
# <<<< >>>>
# 130
# Low
# 2018-06-13 01:53:00
#
#
# 2018-06-12 21:53:00
# D:\5_Data\Transportation\Cameras\SunTrustPark\180612\130\21h15m32s.avi 0:37:28
#
# <<<< >>>>
# 130
# Low
# 2018-06-12 22:50:00
#
#
# 2018-06-12 18:50:00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-196-3e7f6e8f33c6> in <module>()
#       7
#       8 # Run main
# ----> 9 main(labels_fc, labels_fc_camera_field, labels_fc_label_field, labels_fc_datetime_field, video_root_dir)
#
# <ipython-input-195-027a24b7dd41> in main(label_fc, labels_fc_camera_field, labels_fc_label_field, labels_fc_datetime_field, video_root_dir)
#      16
#      17         # Get the path to the right video and the timestamp in the video for the recorded label
# ---> 18         video_path, video_time =  retrieve_video_and_time(camera, label, pandas_timestamp, video_root_dir)
#      19         print(video_path, video_time)
#      20
#
# <ipython-input-187-8c62592b3032> in retrieve_video_and_time(camera, label, pandas_timestamp, video_root_dir)
#      26     camera_dir = "{0}\\{1}\\{2}".format(video_root_dir, yymmdd, camera)
#      27     video_files = os.listdir(camera_dir)
# ---> 28     video_name, video_time = get_videopath_and_video_timestamp_from_label_timestamp(video_files, pdt)
#      29
#      30     return "{0}\\{1}".format(camera_dir, video_name), video_time
#
# <ipython-input-185-20748731f752> in get_videopath_and_video_timestamp_from_label_timestamp(video_files, datetime_object)
#       7         # we need a datetime range...
#       8         start = datetime.datetime.strptime(video_files[ix]+" "+yymmdd, "%Hh%Mm%Ss.avi %y%m%d")
# ----> 9         end = datetime.datetime.strptime(video_files[ix+1]+" "+yymmdd, "%Hh%Mm%Ss.avi %y%m%d")
#      10         in_time_range = start <= datetime_object <= end
#      11
#
# IndexError: list index out of range
